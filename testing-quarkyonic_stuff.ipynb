# %%
import os
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("default")

# from src import TOV_class

pSLM_path = "./testData/"
tov_path = "./TOV_data/Quarkies/"

# %%
tov_files = []
# slm_files = []

for file in os.listdir(f"{tov_path}"):
    if "MR_" in file:
        print(file)
        tov_files.append(file)
    # if "SLM_" in file:
    #     slm_files.append(file)
# Out:
# MR_Quarkyonia_300.00_0.10.dat
# MR_Quarkyonia_500.00_0.30.dat
# MR_Quarkyonia_500.00_0.20.dat
# MR_Quarkyonia_400.00_0.10.dat
# MR_Quarkyonia_400.00_0.20.dat
# MR_Quarkyonia_300.00_0.30.dat
# MR_Quarkyonia_500.00_0.10.dat
# MR_Quarkyonia_300.00_0.20.dat
# MR_Quarkyonia_400.00_0.30.dat

# %%
# dict_10000 = {}

# for tov_file in tov_files:
#     tov_data = np.loadtxt(f"{tov_path}{tov_file}").T
    
#     dict_10000[tov_file] = tov_data
    
#     plt.plot(tov_data[0], tov_data[2])
# #

# plt.xlim(9, 30)
# plt.show()

# %%
file
# Out:
# 'MR_Quarkyonia_400.00_0.30.dat'

# %%
test = 'MR_Quarkyonia_500.00_0.30.dat'

print("variations between 100 vs (200, 500, 10_000) steps in EOS:")
for i, name in zip(np.arange(4), ["radius", "pressure", "mass", "k2"]):
    print(f"\n{name}")
    print("100 - 200 steps:")
    print(dict_100[test][i] - dict_200[test][i])
    print("100 - 500 steps:")
    print(dict_100[test][i] - dict_500[test][i])
    print("100 - 10,000 steps:")
    print(dict_100[test][i] - dict_10000[test][i])
# Out:
# variations between 100 vs (200, 500, 10_000) steps in EOS:
#
# radius
# 100 - 200 steps:
# [-0.0502555 -0.0335036 -0.0251277 -0.0167519 -0.0083759 -0.0083759
#   0.         0.         0.         0.0083759  0.         0.008376
#   0.0083759  0.         0.0083759  0.0083759  0.         0.0083759
#   0.0083759  0.0083759  0.0083759  0.0083759  0.0083759  0.
#   0.0083759  0.008376   0.0083759  0.0083759  0.0083759  0.0083759
#   0.         0.0083759  0.008376   0.0083759  0.0083759  0.
#   0.         0.         0.         0.008376   0.         0.0083759
#   0.         0.         0.         0.         0.0083759  0.
#   0.         0.       ]
# 100 - 500 steps:
# [-0.0670073 -0.0418795 -0.0251277 -0.0167519 -0.0083759  0.
#   0.0083759  0.         0.0083759  0.0083759  0.0083759  0.008376
#   0.0083759  0.0083759  0.0083759  0.0083759  0.0083759  0.0083759
#   0.0083759  0.0083759  0.0083759  0.0083759  0.0083759  0.0083759
# ...
